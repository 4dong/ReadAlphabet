# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation
import os
import scipy as SciPy

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = train_datagen.flow_from_directory(
    directory = 'Training',
    target_size = (32,32),
    batch_size = 32,
    class_mode = 'categorical'

)

test_generator = test_datagen.flow_from_directory(
    directory = 'Testing',
    target_size = (32,32),
    batch_size = 32,
    class_mode = 'categorical'

)
# Out:
# Found 502 images belonging to 26 classes.
# Found 262 images belonging to 26 classes.

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape = (32,32,3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))


model.add(Conv2D(32, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))

model.add(Flatten())
model.add(Dense(units = 128, activation = 'relu'))
model.add(Dense(units = 26, activation = 'softmax'))


model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               147584
# _________________________________________________________________
# dense_1 (Dense)              (None, 26)                3354
# =================================================================
# Total params: 161,082
# Trainable params: 161,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_generator,
                         steps_per_epoch = 16,
                         epochs = 100,
                         validation_data = test_generator,
                         validation_steps = 16)
# Out:
# Epoch 1/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3871 - accuracy: 0.9468WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 16 batches). You may need to use the repeat() function when building your dataset.
# 16/16 [==============================] - 1s 77ms/step - loss: 0.3650 - accuracy: 0.9502 - val_loss: 1.0098 - val_accuracy: 0.8321
# Epoch 2/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1097 - accuracy: 0.9681
# Epoch 3/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0506 - accuracy: 0.9841
# Epoch 4/100
# 16/16 [==============================] - 1s 58ms/step - loss: 0.0203 - accuracy: 0.9960
# Epoch 5/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0275 - accuracy: 0.9900
# Epoch 6/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0104 - accuracy: 0.9960
# Epoch 7/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0166 - accuracy: 0.9920
# Epoch 8/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0258 - accuracy: 0.9900
# Epoch 9/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0155 - accuracy: 0.9980
# Epoch 10/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0146 - accuracy: 0.9940
# Epoch 11/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0110 - accuracy: 0.9960
# Epoch 12/100
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0218 - accuracy: 0.9920
# Epoch 13/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0304 - accuracy: 0.9940
# Epoch 14/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0555 - accuracy: 0.9880
# Epoch 15/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0167 - accuracy: 0.9940
# Epoch 16/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0080 - accuracy: 0.9980
# Epoch 17/100
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0114 - accuracy: 0.9980
# Epoch 18/100
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0155 - accuracy: 0.9920
# Epoch 19/100
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0091 - accuracy: 0.9960
# Epoch 20/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0094 - accuracy: 0.9960
# Epoch 21/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0128 - accuracy: 0.9960
# Epoch 22/100
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 23/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0087 - accuracy: 0.9940
# Epoch 24/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0065 - accuracy: 0.9980
# Epoch 25/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0094 - accuracy: 0.9980
# Epoch 26/100
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0178 - accuracy: 0.9940
# Epoch 27/100
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0310 - accuracy: 0.9920
# Epoch 28/100
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0187 - accuracy: 0.9940
# Epoch 29/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0103 - accuracy: 0.9940
# Epoch 30/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0116 - accuracy: 0.9960
# Epoch 31/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0149 - accuracy: 0.9940
# Epoch 32/100
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 33/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0108 - accuracy: 0.9960
# Epoch 34/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0180 - accuracy: 0.9940
# Epoch 35/100
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0163 - accuracy: 0.9920
# Epoch 36/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0128 - accuracy: 0.9960
# Epoch 37/100
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0101 - accuracy: 0.9960
# Epoch 38/100
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0104 - accuracy: 0.9940
# Epoch 39/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0141 - accuracy: 0.9960
# Epoch 40/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0108 - accuracy: 0.9960
# Epoch 41/100
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0061 - accuracy: 0.9980
# Epoch 42/100
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0112 - accuracy: 0.9940
# Epoch 43/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0157 - accuracy: 0.9940
# Epoch 44/100
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0097 - accuracy: 0.9980
# Epoch 45/100
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0095 - accuracy: 0.9960
# Epoch 46/100
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0142 - accuracy: 0.9960
# Epoch 47/100
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0058 - accuracy: 0.9980
# Epoch 48/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0069 - accuracy: 0.9980
# Epoch 49/100
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 50/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0049 - accuracy: 0.9960
# Epoch 51/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0153 - accuracy: 0.9940
# Epoch 52/100
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0094 - accuracy: 0.9980
# Epoch 53/100
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 54/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0078 - accuracy: 0.9980
# Epoch 55/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0071 - accuracy: 0.9960 0s - loss: 0.0076 - accuracy: 0.99
# Epoch 56/100
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0109 - accuracy: 0.9960
# Epoch 57/100
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0118 - accuracy: 0.9920
# Epoch 58/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0065 - accuracy: 0.9980
# Epoch 59/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0068 - accuracy: 0.9960
# Epoch 60/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0107 - accuracy: 0.9960
# Epoch 61/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0165 - accuracy: 0.9960
# Epoch 62/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0269 - accuracy: 0.9920ETA: 0s - loss: 0.0396
# Epoch 63/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0372 - accuracy: 0.9880
# Epoch 64/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0433 - accuracy: 0.9880
# Epoch 65/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0173 - accuracy: 0.9880
# Epoch 66/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0122 - accuracy: 0.9940
# Epoch 67/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 68/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0214 - accuracy: 0.9960
# Epoch 69/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0084 - accuracy: 0.9960
# Epoch 70/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 71/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0069 - accuracy: 0.9960
# Epoch 72/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0055 - accuracy: 0.9960
# Epoch 73/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0101 - accuracy: 0.9920
# Epoch 74/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0068 - accuracy: 0.9960
# Epoch 75/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 76/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0111 - accuracy: 0.9920
# Epoch 77/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0058 - accuracy: 0.9980
# Epoch 78/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0063 - accuracy: 0.9960
# Epoch 79/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0136 - accuracy: 0.9960
# Epoch 80/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0059 - accuracy: 0.9980
# Epoch 81/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0064 - accuracy: 0.9960
# Epoch 82/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0147 - accuracy: 0.9960
# Epoch 83/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0147 - accuracy: 0.9920
# Epoch 84/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0110 - accuracy: 0.9940
# Epoch 85/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0132 - accuracy: 0.9940
# Epoch 86/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0092 - accuracy: 0.9980
# Epoch 87/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0054 - accuracy: 0.9980
# Epoch 88/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0040 - accuracy: 0.9980
# Epoch 89/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0086 - accuracy: 0.9980
# Epoch 90/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0056 - accuracy: 0.9960
# Epoch 91/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0112 - accuracy: 0.9940
# Epoch 92/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0105 - accuracy: 0.9940
# Epoch 93/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 94/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 95/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0140 - accuracy: 0.9960
# Epoch 96/100
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 97/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0197 - accuracy: 0.9920
# Epoch 98/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0033 - accuracy: 0.9980
# Epoch 99/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0050 - accuracy: 0.9980
# Epoch 100/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0111 - accuracy: 0.9980

# %%
model.save("my_model")
# Out:
# INFO:tensorflow:Assets written to: my_model\assets

# %%
reconstructed_model = keras.models.load_model("my_model")

# %%
def get_result(result):
    if result[0][0] == 1:
        return('a')
    elif result[0][1] == 1:
        return ('b')
    elif result[0][2] == 1:
        return ('c')
    elif result[0][3] == 1:
        return ('d')
    elif result[0][4] == 1:
        return ('e')
    elif result[0][5] == 1:
        return ('f')
    elif result[0][6] == 1:
        return ('g')
    elif result[0][7] == 1:
        return ('h')
    elif result[0][8] == 1:
        return ('i')
    elif result[0][9] == 1:
        return ('j')
    elif result[0][10] == 1:
        return ('k')
    elif result[0][11] == 1:
        return ('l')
    elif result[0][12] == 1:
        return ('m')
    elif result[0][13] == 1:
        return ('n')
    elif result[0][14] == 1:
        return ('o')
    elif result[0][15] == 1:
        return ('p')
    elif result[0][16] == 1:
        return ('q')
    elif result[0][17] == 1:
        return ('r')
    elif result[0][18] == 1:
        return ('s')
    elif result[0][19] == 1:
        return ('t')
    elif result[0][20] == 1:
        return ('u')
    elif result[0][21] == 1:
        return ('v')
    elif result[0][22] == 1:
        return ('w')
    elif result[0][23] == 1:
        return ('x')
    elif result[0][24] == 1:
        return ('y')
    elif result[0][25] == 1:
        return ('z')

# %%
filename = r'Testing\a\27.png'
test_image = image.load_img(filename, target_size = (32,32))
plt.imshow(test_image)
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)

result = reconstructed_model.predict(test_image)
result = get_result(result)
print ('Predicted Alphabet is: {}'.format(result))
# Out:
# Predicted Alphabet is: a
